# %% [markdown]
# ## **感知机(Perceptron)**
# 感知机是二分类模型, 接收多个信号输出一个信号, 感知机的信号只有两种取值0, 1, 例如接收两个输入信号.
#
# ![image.png](attachment:5f3777aa-6374-4405-9aba-a59ef1a4b8bd.png)
#
# x1, x2为输入信号, w1, w2为权重, 每一个节点称之为一个神经元, 输入信号被传递到神经元时, 会分别乘以固定的权重, 神经元会计算到达的输入信号的总和, 只有当前这个值大于阈值theta时才会输出1, 称之为神经元被激活, 设临界值为theta
#
# ![image.png](attachment:4babf63b-dab3-4e0b-87e4-027c8fdb0528.png)
#
# 感知机的多个输入信号每个都有对应的权重, 权重越大对应的信号越重要
