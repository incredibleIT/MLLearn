# %% [markdown]
# ## **网格搜索**
#
# 网格搜索(Grid Search) 是一种系统化的超参数调优方式, 通过遍历预定义的超参数组合, 找到使模型最优的超参数配置, 通过自动化调参, 避免手动试错, 提高效率.
#
# 网格搜索通常嵌套交叉验证, 与交叉验证结合提高调参的可靠性
# - 外层循环: 遍历参数网格中的每个参数组合
# - 内层循环: 对每个参数组合使用交叉验证评估模型性能
