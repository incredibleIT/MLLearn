# %% [markdown]
# ## **牛顿法与拟牛顿法**
#
# #### **1. 牛顿法**
#
# 利用函数的二阶导数信息, 作为学习率来优化参数, 通过迭代来逼近极值点, 收敛速度快, 精度高, 计算复杂容易发散
#
# $$
# x_{k+1} = x_k - H_k^{-1} \nabla f(x_k)
# $$
#
#
# #### **2. 拟牛顿法**
#
# 用一个n阶正定矩阵来替代黑塞矩阵, 减少逆矩阵的计算
#
#
# $$
# x_{k+1} = x_k - B_k^{-1} \nabla f(x_k)
# $$
